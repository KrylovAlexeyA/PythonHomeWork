# %% [markdown]
# ## 2 Requests/urllib + BeautifulSoup

# %% [markdown]
# ###  Скачайте html-код страницы с новостью с любого новостного сайта и, распарсивего с помощью библиотеки Beautiful Soup или любой другой аналогичной,получите текст статьи (без html-тегов или вкраплений java script).

# %%
from bs4 import BeautifulSoup
import urllib
import re
url = "https://habr.com/post/431706/"

# %%
def unlike(elements):
    if elements.parent.name in ['head','style', 'script', 'title','[document]']:
        return False
    else :
        return True    

html = urllib.request.urlopen(url)

beautifulSoup = BeautifulSoup(html, "lxml")
data = beautifulSoup.findAll(text=True)
result = list(filter(unlike, data))
for i in result:
    print (i)
# Out:
# Хабр
#
#
# Geektimes
#
#
# Тостер
#
#
# Мой круг
#
#
# Фрилансим
#
#
#
#
#
#
# Мегапосты:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Публикации
#
#
#
#
#
#
# Пользователи
#
#
#
#
#
#
# Хабы
#
#
#
#
#
#
# Компании
#
#
#
#
#
#
# Песочница
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Войти
#
#
# Регистрация
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# samsergey
#
#
#
#
# вчера в 13:23
#
#
#
#
#
#
# Теория счастья. Случайности неслучайны
#
#
#
#
#
#
#
#
# Занимательные задачки
# ,
#
#
#
#
#
# Математика
# ,
#
#
#
#
#
# Научно-популярное
#
#
#
#
#
#
#
#
#
#
# ...
